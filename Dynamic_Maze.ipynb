# %%
# !pip install gym torch matplotlib imageio
# Out:
# Requirement already satisfied: gym in ./venv_jupyter/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: torch in ./venv_jupyter/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: matplotlib in ./venv_jupyter/lib/python3.12/site-packages (3.10.1)
# Requirement already satisfied: imageio in ./venv_jupyter/lib/python3.12/site-packages (2.37.0)
# Requirement already satisfied: numpy>=1.18.0 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (0.0.8)
# Requirement already satisfied: filelock in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in ./venv_jupyter/lib/python3.12/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in ./venv_jupyter/lib/python3.12/site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv_jupyter/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv_jupyter/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv_jupyter/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %%
import numpy as np
import torch
import random
import time
import imageio
import os
from collections import deque
from gym import Env, spaces
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
import matplotlib

matplotlib.use('Agg')


# Maze Environment
class MazeEnv:
    def __init__(self):
        self.maze, self.start_pos, self.end_pos = self.generate_valid_maze()
        self.agent_pos = list(self.start_pos)
        self.max_steps = 200
        self.current_step = 0

    def generate_maze(self):
        maze = np.ones((6, 6), dtype=int)
        for i in range(6):
            for j in range(6):
                if random.random() < 0.7:
                    maze[i, j] = 0
        maze[0, 0] = maze[5, 5] = 0  # Ensure start and end are free
        return maze

    def generate_start_end_pos(self, maze, avoid_pos=None):
        while True:
            pos = (random.randint(0, 5), random.randint(0, 5))
            if maze[pos] == 0 and pos != avoid_pos:
                return pos

    def is_solvable(self):
        queue = deque([self.start_pos])
        visited = set()
        visited.add(self.start_pos)
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
        while queue:
            x, y = queue.popleft()
            if (x, y) == self.end_pos:
                return True
            for dx, dy in directions:
                nx, ny = x + dx, y + dy
                if 0 <= nx < 6 and 0 <= ny < 6 and self.maze[nx, ny] == 0 and (nx, ny) not in visited:
                    visited.add((nx, ny))
                    queue.append((nx, ny))
        return False

    def generate_valid_maze(self):
        while True:
            self.maze = self.generate_maze()
            self.start_pos = self.generate_start_end_pos(self.maze)
            self.end_pos = self.generate_start_end_pos(self.maze, avoid_pos=self.start_pos)
            if self.is_solvable():
                break

        self.save_maze_image()
        return self.maze, self.start_pos, self.end_pos

    def save_maze_image(self):
        output_dir = './output/maze_register/'
        os.makedirs(output_dir, exist_ok=True)

        maze_name = f"maze_{int(time.time())}.png"
        maze_image_path = os.path.join(output_dir, maze_name)

        fig, ax = plt.subplots(figsize=(5, 5))
        ax.imshow(self.maze, cmap="gray")
        ax.set_title("Generated Maze")
        ax.axis("off")
        plt.savefig(maze_image_path, bbox_inches='tight', pad_inches=0)

        np.save(os.path.join(output_dir, 'maze.npy'), self.maze)
        np.save(os.path.join(output_dir, 'start_pos.npy'), self.start_pos)
        np.save(os.path.join(output_dir, 'end_pos.npy'), self.end_pos)

    def reset(self):
        """Reset the agent's position and step counter."""
        self.agent_pos = list(self.start_pos)
        self.current_step = 0
        return np.array(self.agent_pos, dtype=np.int32)

    def step(self, action):
        self.current_step += 1
        row, col = self.agent_pos

        new_pos = {
            0: [row-1, col],  # Up
            1: [row, col+1],  # Right
            2: [row+1, col],  # Down
            3: [row, col-1]   # Left
        }.get(action, [row, col])

        if 0 <= new_pos[0] < 6 and 0 <= new_pos[1] < 6 and self.maze[tuple(new_pos)] != 1:
            self.agent_pos = new_pos

        done = (self.agent_pos == list(self.end_pos)) or (self.current_step >= self.max_steps)
        reward = 50 if done and self.agent_pos == list(self.end_pos) else -0.1

        return np.array(self.agent_pos, dtype=np.int32), reward, done, {}

    def render(self, mode='rgb_array'):
        fig, ax = plt.subplots(figsize=(5, 5))
        ax.clear()

        grid = np.full((6, 6, 3), [255, 255, 0], dtype=np.uint8)
        grid[self.maze == 1] = [0, 0, 0]           # Walls in black
        grid[self.start_pos] = [0, 200, 0]         # Start in green
        grid[self.end_pos] = [255, 0, 0]           # End in red
        grid[tuple(self.agent_pos)] = [0, 0, 255]  # Agent in blue

        ax.imshow(grid)
        ax.set_xticks([])
        ax.set_yticks([])
        fig.tight_layout(pad=0)

        fig.canvas.draw()
        img = np.frombuffer(fig.canvas.buffer_rgba(), dtype=np.uint8)
        img = img.reshape(fig.canvas.get_width_height()[::-1] + (4,))
        plt.close(fig)
        return img[..., :3]

    def print_maze(self):
        """Print the maze to the terminal."""
        for row in self.maze:
            print(' '.join('⬛' if cell == 1 else '🟨' for cell in row))


# DQN Agent
class DQNAgent:
    def __init__(self, state_size=2, action_size=4, device=None):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
        self.memory = deque(maxlen=10000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.9995
        self.learning_rate = 0.0001
        self.batch_size = 512
        self.tau = 0.01

        self.model = self._build_model().to(self.device)
        self.target_model = self._build_model().to(self.device)
        self.update_target_model()

    def _build_model(self):
        model = nn.Sequential(
            nn.Linear(self.state_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_size)
        )
        return model

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)

        state_normalized = state / 5.0  # Normalize the state
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
        with torch.no_grad():
            return torch.argmax(self.model(state_tensor)).item()

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        minibatch = random.sample(self.memory, self.batch_size)
        states = torch.tensor([t[0] for t in minibatch], dtype=torch.float32).to(self.device)
        actions = torch.tensor([t[1] for t in minibatch], dtype=torch.long).to(self.device)
        rewards = torch.tensor([t[2] for t in minibatch], dtype=torch.float32).to(self.device)
        next_states = torch.tensor([t[3] for t in minibatch], dtype=torch.float32).to(self.device)
        dones = torch.tensor([t[4] for t in minibatch], dtype=torch.float32).to(self.device)

        targets = self.model(states)
        next_q = self.target_model(next_states)

        batch_index = torch.arange(self.batch_size).to(self.device)
        targets[batch_index, actions] = rewards + self.gamma * next_q.max(dim=1)[0] * (1 - dones)

        loss = nn.MSELoss()(targets, self.model(states))
        optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        self.soft_update()

    def soft_update(self):
        """Soft-update the target model parameters."""
        for target_param, param in zip(self.target_model.parameters(), self.model.parameters()):
            target_param.data.copy_((1.0 - self.tau) * target_param.data + self.tau * param.data)

    def save(self, path):
        torch.save(self.model.state_dict(), path + ".weights.pth")

    def load(self, path):
        self.model.load_state_dict(torch.load(path))
        self.update_target_model()


# Dyna-Q Agent
class DynaQAgent:
    def __init__(self, num_states=36, num_actions=4, device=None):
        self.num_states = num_states
        self.num_actions = num_actions
        self.device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
        self.q_table = torch.zeros((num_states, num_actions), device=self.device)
        self.model = {}
        self.alpha = 0.1
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.9995
        self.planning_steps = 10

    def state_to_index(self, state):
        return state[0] * 6 + state[1]

    def act(self, state):
        state_idx = self.state_to_index(state)
        if random.uniform(0, 1) < self.epsilon:
            return random.randrange(self.num_actions)
        return torch.argmax(self.q_table[state_idx]).item()

    def update(self, state, action, reward, next_state, done):
        state_idx = self.state_to_index(state)
        next_state_idx = self.state_to_index(next_state)

        best_next = self.q_table[next_state_idx].max() if not done else 0
        td_target = reward + self.gamma * best_next
        self.q_table[state_idx, action] += self.alpha * (td_target - self.q_table[state_idx, action])

        self.model[(state_idx, action)] = (reward, next_state_idx)

        # Model-based planning
        for (s, a), (r, ns) in random.choices(list(self.model.items()), k=self.planning_steps):
            best_next = self.q_table[ns].max()
            self.q_table[s, a] += self.alpha * (r + self.gamma * best_next - self.q_table[s, a])

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def save(self, path):
        torch.save(self.q_table.cpu(), path + ".qtable.pth")

    def load(self, path):
        self.q_table = torch.load(path).to(self.device)


# Training and Testing Functions
def train(agent_type, num_episodes, model_path, video_dir, device, env=None):
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    model_path = os.path.join(output_dir, 'model_path', model_path)
    video_dir = os.path.join(output_dir, video_dir)
    os.makedirs(model_path, exist_ok=True)
    os.makedirs(video_dir, exist_ok=True)

    if env is None:
        env = MazeEnv()

    if agent_type == 'dqn':
        agent = DQNAgent(device=device)
    elif agent_type == 'dynaq':
        agent = DynaQAgent(device=device)

    rewards, avg_rewards, epsilons, num_steps = [], [], [], []
    best_avg_reward = -float('inf')
    success_train_count = 0

    print(f"Starting training for {num_episodes} episodes...")

    for episode in range(num_episodes):
        state = env.reset()
        total_reward, steps = 0, 0
        done = False
        episode_frames = []

        while not done:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            shaped_reward = reward + (1 - np.sqrt((5 - next_state[0])**2 + (5 - next_state[1])**2) / 14.14) * 0.5

            if agent_type == 'dqn':
                agent.remember(state, action, shaped_reward, next_state, done)
                agent.replay()
            else:
                agent.update(state, action, shaped_reward, next_state, done)

            state = next_state
            total_reward += shaped_reward
            steps += 1

            if episode % 10 == 0 and len(episode_frames) < 100:
                frame = env.render()
                if frame is not None:
                    episode_frames.append(np.clip(frame, 0, 255).astype(np.uint8))

        num_steps.append(steps)
        if episode_frames:
            gif_path = os.path.join(video_dir, f'episode_{episode+1:04d}.gif')
            imageio.mimsave(gif_path, episode_frames, fps=5)

        rewards.append(total_reward)
        avg = np.mean(rewards[-100:]) if rewards else 0
        avg_rewards.append(avg)
        epsilons.append(agent.epsilon)

        if np.array_equal(state, np.array(env.end_pos)):
            success_train_count += 1

        print(f"Episode {episode+1} | Total Reward: {total_reward:.2f} | Avg Reward (Last 100): {avg:.2f} | Steps: {steps} | Epsilon: {agent.epsilon:.3f} | Successes: {success_train_count}")

        if success_train_count > 100:
            print("Early stopping: agent has reached the goal over 100 times.")
            break

        if avg > best_avg_reward:
            agent.save(f"{model_path}_best")
            best_avg_reward = avg

    agent.save(f"{model_path}_best")
    print(f"Training completed! Best average reward: {best_avg_reward:.2f}")


def test(agent_type, model_path, video_dir, device, env=None):
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    model_path = os.path.join(output_dir, 'model_path', model_path)
    video_dir = os.path.join(output_dir, video_dir)
    os.makedirs(video_dir, exist_ok=True)

    if env is None:
        env = MazeEnv()

    if agent_type == 'dqn':
        agent = DQNAgent(device=device)
        agent.load(f"{model_path}_best.weights.pth")
    else:
        agent = DynaQAgent(device=device)
        agent.load(f"{model_path}_best.qtable.pth")
    agent.epsilon = 0.0  # No exploration

    successful, total_steps = 0, []

    for episode in range(10):
        state = env.reset()
        done = False
        frames, steps = [], 0

        while not done and len(frames) < 100:
            action = agent.act(state)
            state, reward, done, _ = env.step(action)
            frames.append(env.render())
            steps += 1

        gif_path = os.path.join(video_dir, f'test_ep_{episode+1}.gif')
        imageio.mimsave(gif_path, frames, fps=5)

        if done:
            successful += 1
        total_steps.append(steps)
        print(f"Test {episode+1}: {'Success' if done else 'Fail'} | Steps: {steps}")

    success_rate = successful / 10
    avg_steps = np.mean(total_steps)
    print(f"\nSuccess Rate: {success_rate:.0%} | Avg Steps per Episode: {avg_steps:.2f}")
    return success_rate


if __name__ == "__main__":
    num_runs = 1  # Number of total runs
    for run in range(num_runs):
        print(f"\n===== Run {run+1} of {num_runs} =====")
        device = 'cpu'
        maze_solved = False
        trial = 1

        while not maze_solved:
            print(f"\n----- Training attempt {trial} -----")
            shared_env = MazeEnv()

            # Train & test with DQN
            train('dqn', 3000, 'maze_agent_dqn', 'dqn_training_gifs', device, env=shared_env)
            dqn_success_rate = test('dqn', 'maze_agent_dqn', 'dqn_test_gifs', device, env=shared_env)

            # Train & test with Dyna-Q
            train('dynaq', 3000, 'maze_agent_dynaq', 'dynaq_training_gifs', device, env=shared_env)
            dynaq_success_rate = test('dynaq', 'maze_agent_dynaq', 'dynaq_test_gifs', device, env=shared_env)

            if dqn_success_rate > 0 or dynaq_success_rate > 0:
                maze_solved = True
                print("The maze was solved by at least one agent!")
            else:
                print("The maze was not solved. Restarting training with a new maze...\n")
                trial += 1
# Out:
# ===== Run 1 of 1 =====
#
# ----- Training attempt 1 -----
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 92.08 | Avg Reward (Last 100): 92.08 | Steps: 170 | Epsilon: 1.000 | Successes: 1
# Episode 2 | Total Reward: 56.35 | Avg Reward (Last 100): 74.21 | Steps: 22 | Epsilon: 1.000 | Successes: 2
# Episode 3 | Total Reward: 60.64 | Avg Reward (Last 100): 69.69 | Steps: 39 | Epsilon: 1.000 | Successes: 3
# Episode 4 | Total Reward: 67.54 | Avg Reward (Last 100): 69.15 | Steps: 64 | Epsilon: 1.000 | Successes: 4
# Episode 5 | Total Reward: 62.89 | Avg Reward (Last 100): 67.90 | Steps: 49 | Epsilon: 1.000 | Successes: 5
# Episode 6 | Total Reward: 48.82 | Avg Reward (Last 100): 64.72 | Steps: 200 | Epsilon: 0.984 | Successes: 5
# Episode 7 | Total Reward: 41.29 | Avg Reward (Last 100): 61.37 | Steps: 200 | Epsilon: 0.890 | Successes: 5
# Episode 8 | Total Reward: 54.55 | Avg Reward (Last 100): 60.52 | Steps: 15 | Epsilon: 0.883 | Successes: 6
# Episode 9 | Total Reward: 56.93 | Avg Reward (Last 100): 60.12 | Steps: 22 | Epsilon: 0.874 | Successes: 7
# Episode 10 | Total Reward: 64.59 | Avg Reward (Last 100): 60.57 | Steps: 57 | Epsilon: 0.849 | Successes: 8
# Episode 11 | Total Reward: 56.35 | Avg Reward (Last 100): 60.18 | Steps: 25 | Epsilon: 0.839 | Successes: 9
# Episode 12 | Total Reward: 70.49 | Avg Reward (Last 100): 61.04 | Steps: 93 | Epsilon: 0.800 | Successes: 10
# Episode 13 | Total Reward: 54.31 | Avg Reward (Last 100): 60.52 | Steps: 15 | Epsilon: 0.794 | Successes: 11
# Episode 14 | Total Reward: 56.96 | Avg Reward (Last 100): 60.27 | Steps: 24 | Epsilon: 0.785 | Successes: 12
# Episode 15 | Total Reward: 75.73 | Avg Reward (Last 100): 61.30 | Steps: 89 | Epsilon: 0.751 | Successes: 13
# Episode 16 | Total Reward: 52.22 | Avg Reward (Last 100): 60.73 | Steps: 7 | Epsilon: 0.748 | Successes: 14
# Episode 17 | Total Reward: 53.44 | Avg Reward (Last 100): 60.30 | Steps: 11 | Epsilon: 0.744 | Successes: 15
# Episode 18 | Total Reward: 58.29 | Avg Reward (Last 100): 60.19 | Steps: 29 | Epsilon: 0.733 | Successes: 16
# Episode 19 | Total Reward: 54.59 | Avg Reward (Last 100): 59.90 | Steps: 16 | Epsilon: 0.728 | Successes: 17
# Episode 20 | Total Reward: 57.63 | Avg Reward (Last 100): 59.78 | Steps: 31 | Epsilon: 0.716 | Successes: 18
# Episode 21 | Total Reward: 72.81 | Avg Reward (Last 100): 60.40 | Steps: 94 | Epsilon: 0.683 | Successes: 19
# Episode 22 | Total Reward: 54.88 | Avg Reward (Last 100): 60.15 | Steps: 17 | Epsilon: 0.678 | Successes: 20
# Episode 23 | Total Reward: 52.79 | Avg Reward (Last 100): 59.83 | Steps: 9 | Epsilon: 0.675 | Successes: 21
# Episode 24 | Total Reward: 57.20 | Avg Reward (Last 100): 59.72 | Steps: 31 | Epsilon: 0.664 | Successes: 22
# Episode 25 | Total Reward: 51.68 | Avg Reward (Last 100): 59.40 | Steps: 5 | Epsilon: 0.663 | Successes: 23
# Episode 26 | Total Reward: 56.93 | Avg Reward (Last 100): 59.31 | Steps: 25 | Epsilon: 0.654 | Successes: 24
# Episode 27 | Total Reward: 57.66 | Avg Reward (Last 100): 59.25 | Steps: 25 | Epsilon: 0.646 | Successes: 25
# Episode 28 | Total Reward: 53.33 | Avg Reward (Last 100): 59.03 | Steps: 11 | Epsilon: 0.643 | Successes: 26
# Episode 29 | Total Reward: 66.75 | Avg Reward (Last 100): 59.30 | Steps: 65 | Epsilon: 0.622 | Successes: 27
# Episode 30 | Total Reward: 54.22 | Avg Reward (Last 100): 59.13 | Steps: 13 | Epsilon: 0.618 | Successes: 28
# Episode 31 | Total Reward: 52.49 | Avg Reward (Last 100): 58.92 | Steps: 8 | Epsilon: 0.616 | Successes: 29
# Episode 32 | Total Reward: 60.56 | Avg Reward (Last 100): 58.97 | Steps: 41 | Epsilon: 0.603 | Successes: 30
# Episode 33 | Total Reward: 62.60 | Avg Reward (Last 100): 59.08 | Steps: 52 | Epsilon: 0.588 | Successes: 31
# Episode 34 | Total Reward: 53.75 | Avg Reward (Last 100): 58.92 | Steps: 12 | Epsilon: 0.584 | Successes: 32
# Episode 35 | Total Reward: 53.81 | Avg Reward (Last 100): 58.78 | Steps: 13 | Epsilon: 0.580 | Successes: 33
# Episode 36 | Total Reward: 54.34 | Avg Reward (Last 100): 58.65 | Steps: 14 | Epsilon: 0.576 | Successes: 34
# Episode 37 | Total Reward: 63.15 | Avg Reward (Last 100): 58.77 | Steps: 47 | Epsilon: 0.563 | Successes: 35
# Episode 38 | Total Reward: 51.68 | Avg Reward (Last 100): 58.59 | Steps: 5 | Epsilon: 0.561 | Successes: 36
# Episode 39 | Total Reward: 60.26 | Avg Reward (Last 100): 58.63 | Steps: 39 | Epsilon: 0.551 | Successes: 37
# Episode 40 | Total Reward: 56.64 | Avg Reward (Last 100): 58.58 | Steps: 27 | Epsilon: 0.543 | Successes: 38
# Episode 41 | Total Reward: 52.86 | Avg Reward (Last 100): 58.44 | Steps: 9 | Epsilon: 0.541 | Successes: 39
# Episode 42 | Total Reward: 54.62 | Avg Reward (Last 100): 58.35 | Steps: 14 | Epsilon: 0.537 | Successes: 40
# Episode 43 | Total Reward: 56.48 | Avg Reward (Last 100): 58.31 | Steps: 23 | Epsilon: 0.531 | Successes: 41
# Episode 44 | Total Reward: 52.79 | Avg Reward (Last 100): 58.18 | Steps: 9 | Epsilon: 0.529 | Successes: 42
# Episode 45 | Total Reward: 53.63 | Avg Reward (Last 100): 58.08 | Steps: 12 | Epsilon: 0.525 | Successes: 43
# Episode 46 | Total Reward: 55.85 | Avg Reward (Last 100): 58.03 | Steps: 20 | Epsilon: 0.520 | Successes: 44
# Episode 47 | Total Reward: 54.59 | Avg Reward (Last 100): 57.96 | Steps: 15 | Epsilon: 0.516 | Successes: 45
# Episode 48 | Total Reward: 53.05 | Avg Reward (Last 100): 57.86 | Steps: 9 | Epsilon: 0.514 | Successes: 46
# Episode 49 | Total Reward: 58.20 | Avg Reward (Last 100): 57.86 | Steps: 29 | Epsilon: 0.507 | Successes: 47
# Episode 50 | Total Reward: 56.75 | Avg Reward (Last 100): 57.84 | Steps: 23 | Epsilon: 0.501 | Successes: 48
# Episode 51 | Total Reward: 54.62 | Avg Reward (Last 100): 57.78 | Steps: 15 | Epsilon: 0.497 | Successes: 49
# Episode 52 | Total Reward: 52.92 | Avg Reward (Last 100): 57.68 | Steps: 9 | Epsilon: 0.495 | Successes: 50
# Episode 53 | Total Reward: 53.10 | Avg Reward (Last 100): 57.60 | Steps: 11 | Epsilon: 0.492 | Successes: 51
# Episode 54 | Total Reward: 73.91 | Avg Reward (Last 100): 57.90 | Steps: 85 | Epsilon: 0.472 | Successes: 52
# Episode 55 | Total Reward: 52.03 | Avg Reward (Last 100): 57.79 | Steps: 6 | Epsilon: 0.470 | Successes: 53
# Episode 56 | Total Reward: 55.39 | Avg Reward (Last 100): 57.75 | Steps: 18 | Epsilon: 0.466 | Successes: 54
# Episode 57 | Total Reward: 52.73 | Avg Reward (Last 100): 57.66 | Steps: 9 | Epsilon: 0.464 | Successes: 55
# Episode 58 | Total Reward: 52.11 | Avg Reward (Last 100): 57.57 | Steps: 7 | Epsilon: 0.462 | Successes: 56
# Episode 59 | Total Reward: 56.78 | Avg Reward (Last 100): 57.55 | Steps: 23 | Epsilon: 0.457 | Successes: 57
# Episode 60 | Total Reward: 53.31 | Avg Reward (Last 100): 57.48 | Steps: 11 | Epsilon: 0.454 | Successes: 58
# Episode 61 | Total Reward: 51.68 | Avg Reward (Last 100): 57.39 | Steps: 5 | Epsilon: 0.453 | Successes: 59
# Episode 62 | Total Reward: 52.96 | Avg Reward (Last 100): 57.32 | Steps: 9 | Epsilon: 0.451 | Successes: 60
# Episode 63 | Total Reward: 52.35 | Avg Reward (Last 100): 57.24 | Steps: 7 | Epsilon: 0.450 | Successes: 61
# Episode 64 | Total Reward: 55.85 | Avg Reward (Last 100): 57.21 | Steps: 19 | Epsilon: 0.445 | Successes: 62
# Episode 65 | Total Reward: 52.93 | Avg Reward (Last 100): 57.15 | Steps: 9 | Epsilon: 0.443 | Successes: 63
# Episode 66 | Total Reward: 52.54 | Avg Reward (Last 100): 57.08 | Steps: 8 | Epsilon: 0.442 | Successes: 64
# Episode 67 | Total Reward: 60.42 | Avg Reward (Last 100): 57.13 | Steps: 36 | Epsilon: 0.434 | Successes: 65
# Episode 68 | Total Reward: 54.26 | Avg Reward (Last 100): 57.09 | Steps: 15 | Epsilon: 0.431 | Successes: 66
# Episode 69 | Total Reward: 54.72 | Avg Reward (Last 100): 57.05 | Steps: 19 | Epsilon: 0.426 | Successes: 67
# Episode 70 | Total Reward: 51.68 | Avg Reward (Last 100): 56.98 | Steps: 5 | Epsilon: 0.425 | Successes: 68
# Episode 71 | Total Reward: 56.26 | Avg Reward (Last 100): 56.97 | Steps: 21 | Epsilon: 0.421 | Successes: 69
# Episode 72 | Total Reward: 53.11 | Avg Reward (Last 100): 56.91 | Steps: 10 | Epsilon: 0.419 | Successes: 70
# Episode 73 | Total Reward: 52.49 | Avg Reward (Last 100): 56.85 | Steps: 8 | Epsilon: 0.417 | Successes: 71
# Episode 74 | Total Reward: 53.46 | Avg Reward (Last 100): 56.81 | Steps: 13 | Epsilon: 0.414 | Successes: 72
# Episode 75 | Total Reward: 53.97 | Avg Reward (Last 100): 56.77 | Steps: 14 | Epsilon: 0.412 | Successes: 73
# Episode 76 | Total Reward: 56.06 | Avg Reward (Last 100): 56.76 | Steps: 21 | Epsilon: 0.407 | Successes: 74
# Episode 77 | Total Reward: 53.60 | Avg Reward (Last 100): 56.72 | Steps: 12 | Epsilon: 0.405 | Successes: 75
# Episode 78 | Total Reward: 57.15 | Avg Reward (Last 100): 56.72 | Steps: 25 | Epsilon: 0.400 | Successes: 76
# Episode 79 | Total Reward: 58.36 | Avg Reward (Last 100): 56.74 | Steps: 29 | Epsilon: 0.394 | Successes: 77
# Episode 80 | Total Reward: 59.00 | Avg Reward (Last 100): 56.77 | Steps: 31 | Epsilon: 0.388 | Successes: 78
# Episode 81 | Total Reward: 65.08 | Avg Reward (Last 100): 56.87 | Steps: 61 | Epsilon: 0.376 | Successes: 79
# Episode 82 | Total Reward: 54.82 | Avg Reward (Last 100): 56.85 | Steps: 16 | Epsilon: 0.373 | Successes: 80
# Episode 83 | Total Reward: 72.08 | Avg Reward (Last 100): 57.03 | Steps: 77 | Epsilon: 0.359 | Successes: 81
# Episode 84 | Total Reward: 63.41 | Avg Reward (Last 100): 57.11 | Steps: 54 | Epsilon: 0.350 | Successes: 82
# Episode 85 | Total Reward: 63.72 | Avg Reward (Last 100): 57.19 | Steps: 53 | Epsilon: 0.341 | Successes: 83
# Episode 86 | Total Reward: 63.64 | Avg Reward (Last 100): 57.26 | Steps: 52 | Epsilon: 0.332 | Successes: 84
# Episode 87 | Total Reward: 57.42 | Avg Reward (Last 100): 57.26 | Steps: 29 | Epsilon: 0.327 | Successes: 85
# Episode 88 | Total Reward: 72.98 | Avg Reward (Last 100): 57.44 | Steps: 91 | Epsilon: 0.312 | Successes: 86
# Episode 89 | Total Reward: 62.92 | Avg Reward (Last 100): 57.50 | Steps: 46 | Epsilon: 0.305 | Successes: 87
# Episode 90 | Total Reward: 66.51 | Avg Reward (Last 100): 57.60 | Steps: 58 | Epsilon: 0.297 | Successes: 88
# Episode 91 | Total Reward: 52.94 | Avg Reward (Last 100): 57.55 | Steps: 10 | Epsilon: 0.295 | Successes: 89
# Episode 92 | Total Reward: 52.23 | Avg Reward (Last 100): 57.49 | Steps: 7 | Epsilon: 0.294 | Successes: 90
# Episode 93 | Total Reward: 54.15 | Avg Reward (Last 100): 57.46 | Steps: 15 | Epsilon: 0.292 | Successes: 91
# Episode 94 | Total Reward: 67.67 | Avg Reward (Last 100): 57.57 | Steps: 69 | Epsilon: 0.282 | Successes: 92
# Episode 95 | Total Reward: 55.03 | Avg Reward (Last 100): 57.54 | Steps: 17 | Epsilon: 0.280 | Successes: 93
# Episode 96 | Total Reward: 54.78 | Avg Reward (Last 100): 57.51 | Steps: 17 | Epsilon: 0.277 | Successes: 94
# Episode 97 | Total Reward: 59.68 | Avg Reward (Last 100): 57.53 | Steps: 35 | Epsilon: 0.272 | Successes: 95
# Episode 98 | Total Reward: 56.74 | Avg Reward (Last 100): 57.53 | Steps: 25 | Epsilon: 0.269 | Successes: 96
# Episode 99 | Total Reward: 61.84 | Avg Reward (Last 100): 57.57 | Steps: 43 | Epsilon: 0.263 | Successes: 97
# Episode 100 | Total Reward: 56.13 | Avg Reward (Last 100): 57.56 | Steps: 21 | Epsilon: 0.261 | Successes: 98
# Episode 101 | Total Reward: 56.69 | Avg Reward (Last 100): 57.20 | Steps: 23 | Epsilon: 0.258 | Successes: 99
# Episode 102 | Total Reward: 58.27 | Avg Reward (Last 100): 57.22 | Steps: 28 | Epsilon: 0.254 | Successes: 100
# Episode 103 | Total Reward: 60.51 | Avg Reward (Last 100): 57.22 | Steps: 36 | Epsilon: 0.249 | Successes: 101
# Early stopping: agent has reached the goal over 100 times.
# Training completed! Best average reward: 92.08
# Test 1: Fail | Steps: 100
# Test 2: Fail | Steps: 100
# Test 3: Fail | Steps: 100
# Test 4: Fail | Steps: 100
# Test 5: Fail | Steps: 100
# Test 6: Fail | Steps: 100
# Test 7: Fail | Steps: 100
# Test 8: Fail | Steps: 100
# Test 9: Fail | Steps: 100
# Test 10: Fail | Steps: 100
#
# Success Rate: 0% | Avg Steps per Episode: 100.00
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 75.15 | Avg Reward (Last 100): 75.15 | Steps: 116 | Epsilon: 0.944 | Successes: 1
# Episode 2 | Total Reward: 61.30 | Avg Reward (Last 100): 68.22 | Steps: 38 | Epsilon: 0.926 | Successes: 2
# Episode 3 | Total Reward: 72.46 | Avg Reward (Last 100): 69.64 | Steps: 89 | Epsilon: 0.886 | Successes: 3
# Episode 4 | Total Reward: 58.75 | Avg Reward (Last 100): 66.91 | Steps: 29 | Epsilon: 0.873 | Successes: 4
# Episode 5 | Total Reward: 64.39 | Avg Reward (Last 100): 66.41 | Steps: 57 | Epsilon: 0.848 | Successes: 5
# Episode 6 | Total Reward: 53.22 | Avg Reward (Last 100): 64.21 | Steps: 10 | Epsilon: 0.844 | Successes: 6
# Episode 7 | Total Reward: 64.45 | Avg Reward (Last 100): 64.25 | Steps: 55 | Epsilon: 0.821 | Successes: 7
# Episode 8 | Total Reward: 59.52 | Avg Reward (Last 100): 63.65 | Steps: 34 | Epsilon: 0.807 | Successes: 8
# Episode 9 | Total Reward: 53.45 | Avg Reward (Last 100): 62.52 | Steps: 11 | Epsilon: 0.803 | Successes: 9
# Episode 10 | Total Reward: 56.65 | Avg Reward (Last 100): 61.93 | Steps: 25 | Epsilon: 0.793 | Successes: 10
# Episode 11 | Total Reward: 59.39 | Avg Reward (Last 100): 61.70 | Steps: 33 | Epsilon: 0.780 | Successes: 11
# Episode 12 | Total Reward: 57.39 | Avg Reward (Last 100): 61.34 | Steps: 25 | Epsilon: 0.770 | Successes: 12
# Episode 13 | Total Reward: 56.54 | Avg Reward (Last 100): 60.97 | Steps: 25 | Epsilon: 0.761 | Successes: 13
# Episode 14 | Total Reward: 57.21 | Avg Reward (Last 100): 60.71 | Steps: 28 | Epsilon: 0.750 | Successes: 14
# Episode 15 | Total Reward: 58.61 | Avg Reward (Last 100): 60.57 | Steps: 32 | Epsilon: 0.738 | Successes: 15
# Episode 16 | Total Reward: 57.77 | Avg Reward (Last 100): 60.39 | Steps: 31 | Epsilon: 0.727 | Successes: 16
# Episode 17 | Total Reward: 60.94 | Avg Reward (Last 100): 60.42 | Steps: 40 | Epsilon: 0.712 | Successes: 17
# Episode 18 | Total Reward: 56.01 | Avg Reward (Last 100): 60.18 | Steps: 21 | Epsilon: 0.705 | Successes: 18
# Episode 19 | Total Reward: 55.50 | Avg Reward (Last 100): 59.93 | Steps: 18 | Epsilon: 0.699 | Successes: 19
# Episode 20 | Total Reward: 57.70 | Avg Reward (Last 100): 59.82 | Steps: 30 | Epsilon: 0.688 | Successes: 20
# Episode 21 | Total Reward: 56.05 | Avg Reward (Last 100): 59.64 | Steps: 22 | Epsilon: 0.681 | Successes: 21
# Episode 22 | Total Reward: 53.22 | Avg Reward (Last 100): 59.35 | Steps: 11 | Epsilon: 0.677 | Successes: 22
# Episode 23 | Total Reward: 56.51 | Avg Reward (Last 100): 59.22 | Steps: 22 | Epsilon: 0.670 | Successes: 23
# Episode 24 | Total Reward: 53.66 | Avg Reward (Last 100): 58.99 | Steps: 14 | Epsilon: 0.665 | Successes: 24
# Episode 25 | Total Reward: 58.27 | Avg Reward (Last 100): 58.96 | Steps: 28 | Epsilon: 0.656 | Successes: 25
# Episode 26 | Total Reward: 55.61 | Avg Reward (Last 100): 58.84 | Steps: 21 | Epsilon: 0.649 | Successes: 26
# Episode 27 | Total Reward: 55.43 | Avg Reward (Last 100): 58.71 | Steps: 20 | Epsilon: 0.642 | Successes: 27
# Episode 28 | Total Reward: 54.77 | Avg Reward (Last 100): 58.57 | Steps: 16 | Epsilon: 0.637 | Successes: 28
# Episode 29 | Total Reward: 54.30 | Avg Reward (Last 100): 58.42 | Steps: 14 | Epsilon: 0.633 | Successes: 29
# Episode 30 | Total Reward: 53.98 | Avg Reward (Last 100): 58.27 | Steps: 13 | Epsilon: 0.629 | Successes: 30
# Episode 31 | Total Reward: 52.26 | Avg Reward (Last 100): 58.08 | Steps: 7 | Epsilon: 0.626 | Successes: 31
# Episode 32 | Total Reward: 53.24 | Avg Reward (Last 100): 57.93 | Steps: 10 | Epsilon: 0.623 | Successes: 32
# Episode 33 | Total Reward: 54.94 | Avg Reward (Last 100): 57.84 | Steps: 17 | Epsilon: 0.618 | Successes: 33
# Episode 34 | Total Reward: 54.49 | Avg Reward (Last 100): 57.74 | Steps: 15 | Epsilon: 0.613 | Successes: 34
# Episode 35 | Total Reward: 55.21 | Avg Reward (Last 100): 57.67 | Steps: 17 | Epsilon: 0.608 | Successes: 35
# Episode 36 | Total Reward: 56.34 | Avg Reward (Last 100): 57.63 | Steps: 21 | Epsilon: 0.602 | Successes: 36
# Episode 37 | Total Reward: 53.27 | Avg Reward (Last 100): 57.51 | Steps: 11 | Epsilon: 0.599 | Successes: 37
# Episode 38 | Total Reward: 56.59 | Avg Reward (Last 100): 57.49 | Steps: 22 | Epsilon: 0.592 | Successes: 38
# Episode 39 | Total Reward: 52.61 | Avg Reward (Last 100): 57.36 | Steps: 8 | Epsilon: 0.590 | Successes: 39
# Episode 40 | Total Reward: 53.33 | Avg Reward (Last 100): 57.26 | Steps: 12 | Epsilon: 0.586 | Successes: 40
# Episode 41 | Total Reward: 53.40 | Avg Reward (Last 100): 57.17 | Steps: 11 | Epsilon: 0.583 | Successes: 41
# Episode 42 | Total Reward: 52.72 | Avg Reward (Last 100): 57.06 | Steps: 9 | Epsilon: 0.580 | Successes: 42
# Episode 43 | Total Reward: 53.10 | Avg Reward (Last 100): 56.97 | Steps: 10 | Epsilon: 0.577 | Successes: 43
# Episode 44 | Total Reward: 53.87 | Avg Reward (Last 100): 56.90 | Steps: 14 | Epsilon: 0.573 | Successes: 44
# Episode 45 | Total Reward: 52.38 | Avg Reward (Last 100): 56.80 | Steps: 7 | Epsilon: 0.571 | Successes: 45
# Episode 46 | Total Reward: 51.68 | Avg Reward (Last 100): 56.69 | Steps: 5 | Epsilon: 0.570 | Successes: 46
# Episode 47 | Total Reward: 53.97 | Avg Reward (Last 100): 56.63 | Steps: 13 | Epsilon: 0.566 | Successes: 47
# Episode 48 | Total Reward: 53.74 | Avg Reward (Last 100): 56.57 | Steps: 13 | Epsilon: 0.563 | Successes: 48
# Episode 49 | Total Reward: 54.15 | Avg Reward (Last 100): 56.52 | Steps: 14 | Epsilon: 0.559 | Successes: 49
# Episode 50 | Total Reward: 53.87 | Avg Reward (Last 100): 56.47 | Steps: 12 | Epsilon: 0.555 | Successes: 50
# Episode 51 | Total Reward: 53.44 | Avg Reward (Last 100): 56.41 | Steps: 12 | Epsilon: 0.552 | Successes: 51
# Episode 52 | Total Reward: 56.40 | Avg Reward (Last 100): 56.41 | Steps: 19 | Epsilon: 0.547 | Successes: 52
# Episode 53 | Total Reward: 53.36 | Avg Reward (Last 100): 56.35 | Steps: 12 | Epsilon: 0.544 | Successes: 53
# Episode 54 | Total Reward: 53.88 | Avg Reward (Last 100): 56.30 | Steps: 13 | Epsilon: 0.540 | Successes: 54
# Episode 55 | Total Reward: 52.16 | Avg Reward (Last 100): 56.23 | Steps: 7 | Epsilon: 0.538 | Successes: 55
# Episode 56 | Total Reward: 53.45 | Avg Reward (Last 100): 56.18 | Steps: 11 | Epsilon: 0.535 | Successes: 56
# Episode 57 | Total Reward: 55.48 | Avg Reward (Last 100): 56.17 | Steps: 17 | Epsilon: 0.531 | Successes: 57
# Episode 58 | Total Reward: 53.25 | Avg Reward (Last 100): 56.12 | Steps: 11 | Epsilon: 0.528 | Successes: 58
# Episode 59 | Total Reward: 52.37 | Avg Reward (Last 100): 56.05 | Steps: 8 | Epsilon: 0.526 | Successes: 59
# Episode 60 | Total Reward: 52.23 | Avg Reward (Last 100): 55.99 | Steps: 7 | Epsilon: 0.524 | Successes: 60
# Episode 61 | Total Reward: 52.24 | Avg Reward (Last 100): 55.93 | Steps: 7 | Epsilon: 0.522 | Successes: 61
# Episode 62 | Total Reward: 53.95 | Avg Reward (Last 100): 55.90 | Steps: 13 | Epsilon: 0.519 | Successes: 62
# Episode 63 | Total Reward: 51.68 | Avg Reward (Last 100): 55.83 | Steps: 5 | Epsilon: 0.517 | Successes: 63
# Episode 64 | Total Reward: 54.48 | Avg Reward (Last 100): 55.81 | Steps: 17 | Epsilon: 0.513 | Successes: 64
# Episode 65 | Total Reward: 58.86 | Avg Reward (Last 100): 55.86 | Steps: 31 | Epsilon: 0.505 | Successes: 65
# Episode 66 | Total Reward: 52.70 | Avg Reward (Last 100): 55.81 | Steps: 9 | Epsilon: 0.503 | Successes: 66
# Episode 67 | Total Reward: 52.00 | Avg Reward (Last 100): 55.75 | Steps: 6 | Epsilon: 0.501 | Successes: 67
# Episode 68 | Total Reward: 53.22 | Avg Reward (Last 100): 55.71 | Steps: 10 | Epsilon: 0.499 | Successes: 68
# Episode 69 | Total Reward: 52.74 | Avg Reward (Last 100): 55.67 | Steps: 9 | Epsilon: 0.496 | Successes: 69
# Episode 70 | Total Reward: 54.73 | Avg Reward (Last 100): 55.66 | Steps: 16 | Epsilon: 0.493 | Successes: 70
# Episode 71 | Total Reward: 53.10 | Avg Reward (Last 100): 55.62 | Steps: 10 | Epsilon: 0.490 | Successes: 71
# Episode 72 | Total Reward: 57.95 | Avg Reward (Last 100): 55.65 | Steps: 26 | Epsilon: 0.484 | Successes: 72
# Episode 73 | Total Reward: 53.37 | Avg Reward (Last 100): 55.62 | Steps: 10 | Epsilon: 0.481 | Successes: 73
# Episode 74 | Total Reward: 54.74 | Avg Reward (Last 100): 55.61 | Steps: 17 | Epsilon: 0.477 | Successes: 74
# Episode 75 | Total Reward: 54.10 | Avg Reward (Last 100): 55.59 | Steps: 13 | Epsilon: 0.474 | Successes: 75
# Episode 76 | Total Reward: 52.61 | Avg Reward (Last 100): 55.55 | Steps: 8 | Epsilon: 0.472 | Successes: 76
# Episode 77 | Total Reward: 53.51 | Avg Reward (Last 100): 55.52 | Steps: 11 | Epsilon: 0.470 | Successes: 77
# Episode 78 | Total Reward: 54.02 | Avg Reward (Last 100): 55.50 | Steps: 13 | Epsilon: 0.467 | Successes: 78
# Episode 79 | Total Reward: 55.39 | Avg Reward (Last 100): 55.50 | Steps: 18 | Epsilon: 0.462 | Successes: 79
# Episode 80 | Total Reward: 51.68 | Avg Reward (Last 100): 55.46 | Steps: 5 | Epsilon: 0.461 | Successes: 80
# Episode 81 | Total Reward: 56.71 | Avg Reward (Last 100): 55.47 | Steps: 23 | Epsilon: 0.456 | Successes: 81
# Episode 82 | Total Reward: 52.33 | Avg Reward (Last 100): 55.43 | Steps: 7 | Epsilon: 0.454 | Successes: 82
# Episode 83 | Total Reward: 54.28 | Avg Reward (Last 100): 55.42 | Steps: 14 | Epsilon: 0.451 | Successes: 83
# Episode 84 | Total Reward: 53.29 | Avg Reward (Last 100): 55.39 | Steps: 11 | Epsilon: 0.449 | Successes: 84
# Episode 85 | Total Reward: 55.24 | Avg Reward (Last 100): 55.39 | Steps: 18 | Epsilon: 0.445 | Successes: 85
# Episode 86 | Total Reward: 54.05 | Avg Reward (Last 100): 55.38 | Steps: 13 | Epsilon: 0.442 | Successes: 86
# Episode 87 | Total Reward: 53.31 | Avg Reward (Last 100): 55.35 | Steps: 10 | Epsilon: 0.440 | Successes: 87
# Episode 88 | Total Reward: 52.41 | Avg Reward (Last 100): 55.32 | Steps: 8 | Epsilon: 0.438 | Successes: 88
# Episode 89 | Total Reward: 54.74 | Avg Reward (Last 100): 55.31 | Steps: 16 | Epsilon: 0.434 | Successes: 89
# Episode 90 | Total Reward: 53.10 | Avg Reward (Last 100): 55.29 | Steps: 10 | Epsilon: 0.432 | Successes: 90
# Episode 91 | Total Reward: 52.56 | Avg Reward (Last 100): 55.26 | Steps: 8 | Epsilon: 0.431 | Successes: 91
# Episode 92 | Total Reward: 54.99 | Avg Reward (Last 100): 55.25 | Steps: 17 | Epsilon: 0.427 | Successes: 92
# Episode 93 | Total Reward: 53.31 | Avg Reward (Last 100): 55.23 | Steps: 10 | Epsilon: 0.425 | Successes: 93
# Episode 94 | Total Reward: 51.68 | Avg Reward (Last 100): 55.20 | Steps: 5 | Epsilon: 0.424 | Successes: 94
# Episode 95 | Total Reward: 52.61 | Avg Reward (Last 100): 55.17 | Steps: 8 | Epsilon: 0.422 | Successes: 95
# Episode 96 | Total Reward: 55.72 | Avg Reward (Last 100): 55.17 | Steps: 20 | Epsilon: 0.418 | Successes: 96
# Episode 97 | Total Reward: 53.59 | Avg Reward (Last 100): 55.16 | Steps: 13 | Epsilon: 0.415 | Successes: 97
# Episode 98 | Total Reward: 51.68 | Avg Reward (Last 100): 55.12 | Steps: 5 | Epsilon: 0.414 | Successes: 98
# Episode 99 | Total Reward: 51.93 | Avg Reward (Last 100): 55.09 | Steps: 6 | Epsilon: 0.413 | Successes: 99
# Episode 100 | Total Reward: 52.91 | Avg Reward (Last 100): 55.07 | Steps: 9 | Epsilon: 0.411 | Successes: 100
# Episode 101 | Total Reward: 52.15 | Avg Reward (Last 100): 54.84 | Steps: 7 | Epsilon: 0.410 | Successes: 101
# Early stopping: agent has reached the goal over 100 times.
# Training completed! Best average reward: 75.15
# Test 1: Success | Steps: 5
# Test 2: Success | Steps: 5
# Test 3: Success | Steps: 5
# Test 4: Success | Steps: 5
# Test 5: Success | Steps: 5
# Test 6: Success | Steps: 5
# Test 7: Success | Steps: 5
# Test 8: Success | Steps: 5
# Test 9: Success | Steps: 5
# Test 10: Success | Steps: 5
#
# Success Rate: 100% | Avg Steps per Episode: 5.00
# The maze was solved by at least one agent!
