# %%
# !pip install gym torch matplotlib imageio
# Out:
# Requirement already satisfied: gym in ./venv_jupyter/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: torch in ./venv_jupyter/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: matplotlib in ./venv_jupyter/lib/python3.12/site-packages (3.10.1)
# Requirement already satisfied: imageio in ./venv_jupyter/lib/python3.12/site-packages (2.37.0)
# Requirement already satisfied: numpy>=1.18.0 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in ./venv_jupyter/lib/python3.12/site-packages (from gym) (0.0.8)
# Requirement already satisfied: filelock in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in ./venv_jupyter/lib/python3.12/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in ./venv_jupyter/lib/python3.12/site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./venv_jupyter/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv_jupyter/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv_jupyter/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv_jupyter/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv_jupyter/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %%
import numpy as np
import torch
import random
import time
import imageio
import os
from collections import deque
from gym import Env, spaces
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim
import matplotlib

matplotlib.use('Agg')


# Maze Environment
class MazeEnv:
    def __init__(self):
        self.maze, self.start_pos, self.end_pos = self.generate_valid_maze()
        self.agent_pos = list(self.start_pos)
        self.max_steps = 200
        self.current_step = 0

    def generate_maze(self):
        maze = np.ones((6, 6), dtype=int)
        for i in range(6):
            for j in range(6):
                if random.random() < 0.7:
                    maze[i, j] = 0
        maze[0, 0] = maze[5, 5] = 0  # Ensure start and end are free
        return maze

    def generate_start_end_pos(self, maze, avoid_pos=None):
        while True:
            pos = (random.randint(0, 5), random.randint(0, 5))
            if maze[pos] == 0 and pos != avoid_pos:
                return pos

    def is_solvable(self):
        queue = deque([self.start_pos])
        visited = set()
        visited.add(self.start_pos)
        directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
        while queue:
            x, y = queue.popleft()
            if (x, y) == self.end_pos:
                return True
            for dx, dy in directions:
                nx, ny = x + dx, y + dy
                if 0 <= nx < 6 and 0 <= ny < 6 and self.maze[nx, ny] == 0 and (nx, ny) not in visited:
                    visited.add((nx, ny))
                    queue.append((nx, ny))
        return False

    def generate_valid_maze(self):
        while True:
            self.maze = self.generate_maze()
            self.start_pos = self.generate_start_end_pos(self.maze)
            self.end_pos = self.generate_start_end_pos(self.maze, avoid_pos=self.start_pos)
            if self.is_solvable():
                break

        self.save_maze_image()
        return self.maze, self.start_pos, self.end_pos

    def save_maze_image(self):
        output_dir = './output/maze_register/'
        os.makedirs(output_dir, exist_ok=True)

        maze_name = f"maze_{int(time.time())}.png"
        maze_image_path = os.path.join(output_dir, maze_name)

        fig, ax = plt.subplots(figsize=(5, 5))
        ax.imshow(self.maze, cmap="gray")
        ax.set_title("Generated Maze")
        ax.axis("off")
        plt.savefig(maze_image_path, bbox_inches='tight', pad_inches=0)

        np.save(os.path.join(output_dir, 'maze.npy'), self.maze)
        np.save(os.path.join(output_dir, 'start_pos.npy'), self.start_pos)
        np.save(os.path.join(output_dir, 'end_pos.npy'), self.end_pos)

    def reset(self):
        """Reset the agent's position and step counter."""
        self.agent_pos = list(self.start_pos)
        self.current_step = 0
        return np.array(self.agent_pos, dtype=np.int32)

    def step(self, action):
        self.current_step += 1
        row, col = self.agent_pos

        new_pos = {
            0: [row-1, col],  # Up
            1: [row, col+1],  # Right
            2: [row+1, col],  # Down
            3: [row, col-1]   # Left
        }.get(action, [row, col])

        if 0 <= new_pos[0] < 6 and 0 <= new_pos[1] < 6 and self.maze[tuple(new_pos)] != 1:
            self.agent_pos = new_pos

        done = (self.agent_pos == list(self.end_pos)) or (self.current_step >= self.max_steps)
        reward = 50 if done and self.agent_pos == list(self.end_pos) else -0.1

        return np.array(self.agent_pos, dtype=np.int32), reward, done, {}

    def render(self, mode='rgb_array'):
        fig, ax = plt.subplots(figsize=(5, 5))
        ax.clear()

        grid = np.full((6, 6, 3), [255, 255, 0], dtype=np.uint8)
        grid[self.maze == 1] = [0, 0, 0]           # Walls in black
        grid[self.start_pos] = [0, 200, 0]         # Start in green
        grid[self.end_pos] = [255, 0, 0]           # End in red
        grid[tuple(self.agent_pos)] = [0, 0, 255]  # Agent in blue

        ax.imshow(grid)
        ax.set_xticks([])
        ax.set_yticks([])
        fig.tight_layout(pad=0)

        fig.canvas.draw()
        img = np.frombuffer(fig.canvas.buffer_rgba(), dtype=np.uint8)
        img = img.reshape(fig.canvas.get_width_height()[::-1] + (4,))
        plt.close(fig)
        return img[..., :3]

    def print_maze(self):
        """Print the maze to the terminal."""
        for row in self.maze:
            print(' '.join('⬛' if cell == 1 else '🟨' for cell in row))


# DQN Agent
class DQNAgent:
    def __init__(self, state_size=2, action_size=4, device=None):
        self.state_size = state_size
        self.action_size = action_size
        self.device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
        self.memory = deque(maxlen=10000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.9995
        self.learning_rate = 0.0001
        self.batch_size = 512
        self.tau = 0.01

        self.model = self._build_model().to(self.device)
        self.target_model = self._build_model().to(self.device)
        self.update_target_model()

    def _build_model(self):
        model = nn.Sequential(
            nn.Linear(self.state_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_size)
        )
        return model

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)

        state_normalized = state / 5.0  # Normalize the state
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(self.device)
        with torch.no_grad():
            return torch.argmax(self.model(state_tensor)).item()

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        minibatch = random.sample(self.memory, self.batch_size)
        states = torch.tensor([t[0] for t in minibatch], dtype=torch.float32).to(self.device)
        actions = torch.tensor([t[1] for t in minibatch], dtype=torch.long).to(self.device)
        rewards = torch.tensor([t[2] for t in minibatch], dtype=torch.float32).to(self.device)
        next_states = torch.tensor([t[3] for t in minibatch], dtype=torch.float32).to(self.device)
        dones = torch.tensor([t[4] for t in minibatch], dtype=torch.float32).to(self.device)

        targets = self.model(states)
        next_q = self.target_model(next_states)

        batch_index = torch.arange(self.batch_size).to(self.device)
        targets[batch_index, actions] = rewards + self.gamma * next_q.max(dim=1)[0] * (1 - dones)

        loss = nn.MSELoss()(targets, self.model(states))
        optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        self.soft_update()

    def soft_update(self):
        """Soft-update the target model parameters."""
        for target_param, param in zip(self.target_model.parameters(), self.model.parameters()):
            target_param.data.copy_((1.0 - self.tau) * target_param.data + self.tau * param.data)

    def save(self, path):
        torch.save(self.model.state_dict(), path + ".weights.pth")

    def load(self, path):
        self.model.load_state_dict(torch.load(path))
        self.update_target_model()


# Dyna-Q Agent
class DynaQAgent:
    def __init__(self, num_states=36, num_actions=4, device=None):
        self.num_states = num_states
        self.num_actions = num_actions
        self.device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
        self.q_table = torch.zeros((num_states, num_actions), device=self.device)
        self.model = {}
        self.alpha = 0.1
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.9995
        self.planning_steps = 10

    def state_to_index(self, state):
        return state[0] * 6 + state[1]

    def act(self, state):
        state_idx = self.state_to_index(state)
        if random.uniform(0, 1) < self.epsilon:
            return random.randrange(self.num_actions)
        return torch.argmax(self.q_table[state_idx]).item()

    def update(self, state, action, reward, next_state, done):
        state_idx = self.state_to_index(state)
        next_state_idx = self.state_to_index(next_state)

        best_next = self.q_table[next_state_idx].max() if not done else 0
        td_target = reward + self.gamma * best_next
        self.q_table[state_idx, action] += self.alpha * (td_target - self.q_table[state_idx, action])

        self.model[(state_idx, action)] = (reward, next_state_idx)

        # Model-based planning
        for (s, a), (r, ns) in random.choices(list(self.model.items()), k=self.planning_steps):
            best_next = self.q_table[ns].max()
            self.q_table[s, a] += self.alpha * (r + self.gamma * best_next - self.q_table[s, a])

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def save(self, path):
        torch.save(self.q_table.cpu(), path + ".qtable.pth")

    def load(self, path):
        self.q_table = torch.load(path).to(self.device)


# Training and Testing Functions
def train(agent_type, num_episodes, model_path, video_dir, device, env=None):
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    model_path = os.path.join(output_dir, 'model_path', model_path)
    video_dir = os.path.join(output_dir, video_dir)
    os.makedirs(model_path, exist_ok=True)
    os.makedirs(video_dir, exist_ok=True)

    if env is None:
        env = MazeEnv()

    if agent_type == 'dqn':
        agent = DQNAgent(device=device)
    elif agent_type == 'dynaq':
        agent = DynaQAgent(device=device)

    rewards, avg_rewards, epsilons, num_steps = [], [], [], []
    best_avg_reward = -float('inf')
    success_train_count = 0

    print(f"Starting training for {num_episodes} episodes...")

    for episode in range(num_episodes):
        state = env.reset()
        total_reward, steps = 0, 0
        done = False
        episode_frames = []

        while not done:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            shaped_reward = reward + (1 - np.sqrt((5 - next_state[0])**2 + (5 - next_state[1])**2) / 14.14) * 0.5

            if agent_type == 'dqn':
                agent.remember(state, action, shaped_reward, next_state, done)
                agent.replay()
            else:
                agent.update(state, action, shaped_reward, next_state, done)

            state = next_state
            total_reward += shaped_reward
            steps += 1

            if episode % 10 == 0 and len(episode_frames) < 100:
                frame = env.render()
                if frame is not None:
                    episode_frames.append(np.clip(frame, 0, 255).astype(np.uint8))

        num_steps.append(steps)
        if episode_frames:
            gif_path = os.path.join(video_dir, f'episode_{episode+1:04d}.gif')
            imageio.mimsave(gif_path, episode_frames, fps=5)

        rewards.append(total_reward)
        avg = np.mean(rewards[-100:]) if rewards else 0
        avg_rewards.append(avg)
        epsilons.append(agent.epsilon)

        if np.array_equal(state, np.array(env.end_pos)):
            success_train_count += 1

        print(f"Episode {episode+1} | Total Reward: {total_reward:.2f} | Avg Reward (Last 100): {avg:.2f} | Steps: {steps} | Epsilon: {agent.epsilon:.3f} | Successes: {success_train_count}")

        if success_train_count > 100:
            print("Early stopping: agent has reached the goal over 100 times.")
            break

        if avg > best_avg_reward:
            agent.save(f"{model_path}_best")
            best_avg_reward = avg

    agent.save(f"{model_path}_best")
    print(f"Training completed! Best average reward: {best_avg_reward:.2f}")


def test(agent_type, model_path, video_dir, device, env=None):
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    model_path = os.path.join(output_dir, 'model_path', model_path)
    video_dir = os.path.join(output_dir, video_dir)
    os.makedirs(video_dir, exist_ok=True)

    if env is None:
        env = MazeEnv()

    if agent_type == 'dqn':
        agent = DQNAgent(device=device)
        agent.load(f"{model_path}_best.weights.pth")
    else:
        agent = DynaQAgent(device=device)
        agent.load(f"{model_path}_best.qtable.pth")
    agent.epsilon = 0.0  # No exploration

    successful, total_steps = 0, []

    for episode in range(10):
        state = env.reset()
        done = False
        frames, steps = [], 0

        while not done and len(frames) < 100:
            action = agent.act(state)
            state, reward, done, _ = env.step(action)
            frames.append(env.render())
            steps += 1

        gif_path = os.path.join(video_dir, f'test_ep_{episode+1}.gif')
        imageio.mimsave(gif_path, frames, fps=5)

        if done:
            successful += 1
        total_steps.append(steps)
        print(f"Test {episode+1}: {'Success' if done else 'Fail'} | Steps: {steps}")

    success_rate = successful / 10
    avg_steps = np.mean(total_steps)
    print(f"\nSuccess Rate: {success_rate:.0%} | Avg Steps per Episode: {avg_steps:.2f}")
    return success_rate


if __name__ == "__main__":
    num_runs = 1  # Number of total runs
    for run in range(num_runs):
        print(f"\n===== Run {run+1} of {num_runs} =====")
        device = 'cpu'
        maze_solved = False
        trial = 1

        while not maze_solved:
            print(f"\n----- Training attempt {trial} -----")
            shared_env = MazeEnv()

            # Train & test with DQN
            train('dqn', 3000, 'maze_agent_dqn', 'dqn_training_gifs', device, env=shared_env)
            dqn_success_rate = test('dqn', 'maze_agent_dqn', 'dqn_test_gifs', device, env=shared_env)

            # Train & test with Dyna-Q
            train('dynaq', 3000, 'maze_agent_dynaq', 'dynaq_training_gifs', device, env=shared_env)
            dynaq_success_rate = test('dynaq', 'maze_agent_dynaq', 'dynaq_test_gifs', device, env=shared_env)

            if dqn_success_rate > 0 or dynaq_success_rate > 0:
                maze_solved = True
                print("The maze was solved by at least one agent!")
            else:
                print("The maze was not solved. Restarting training with a new maze...\n")
                trial += 1
# Out:
# ===== Ejecución 1 de 5 =====
#
# ----- Intento de entrenamiento 1 -----
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 59.01 | Avg Reward (Last 100): 59.01 | Steps: 32 | Epsilon: 1.000 | Successes: 1
# Episode 2 | Total Reward: 54.45 | Avg Reward (Last 100): 56.73 | Steps: 24 | Epsilon: 1.000 | Successes: 2
# Episode 3 | Total Reward: 43.60 | Avg Reward (Last 100): 52.35 | Steps: 200 | Epsilon: 1.000 | Successes: 2
# Episode 4 | Total Reward: 61.71 | Avg Reward (Last 100): 54.69 | Steps: 65 | Epsilon: 1.000 | Successes: 3
# Episode 5 | Total Reward: 42.25 | Avg Reward (Last 100): 52.20 | Steps: 200 | Epsilon: 0.995 | Successes: 3
# Episode 6 | Total Reward: 56.20 | Avg Reward (Last 100): 52.87 | Steps: 31 | Epsilon: 0.980 | Successes: 4
# Episode 7 | Total Reward: 43.79 | Avg Reward (Last 100): 51.57 | Steps: 200 | Epsilon: 0.886 | Successes: 4
# Episode 8 | Total Reward: 60.27 | Avg Reward (Last 100): 52.66 | Steps: 50 | Epsilon: 0.865 | Successes: 5
# Episode 9 | Total Reward: 42.12 | Avg Reward (Last 100): 51.49 | Steps: 200 | Epsilon: 0.782 | Successes: 5
# Episode 10 | Total Reward: 72.06 | Avg Reward (Last 100): 53.55 | Steps: 105 | Epsilon: 0.742 | Successes: 6
# Episode 11 | Total Reward: 58.74 | Avg Reward (Last 100): 54.02 | Steps: 44 | Epsilon: 0.726 | Successes: 7
# Episode 12 | Total Reward: 53.57 | Avg Reward (Last 100): 53.98 | Steps: 17 | Epsilon: 0.720 | Successes: 8
# Episode 13 | Total Reward: 78.92 | Avg Reward (Last 100): 55.90 | Steps: 98 | Epsilon: 0.686 | Successes: 9
# Episode 14 | Total Reward: 52.90 | Avg Reward (Last 100): 55.68 | Steps: 13 | Epsilon: 0.681 | Successes: 10
# Episode 15 | Total Reward: 88.76 | Avg Reward (Last 100): 57.89 | Steps: 116 | Epsilon: 0.643 | Successes: 11
# Episode 16 | Total Reward: 58.20 | Avg Reward (Last 100): 57.91 | Steps: 37 | Epsilon: 0.631 | Successes: 12
# Episode 17 | Total Reward: 51.91 | Avg Reward (Last 100): 57.56 | Steps: 9 | Epsilon: 0.628 | Successes: 13
# Episode 18 | Total Reward: 59.97 | Avg Reward (Last 100): 57.69 | Steps: 45 | Epsilon: 0.614 | Successes: 14
# Episode 19 | Total Reward: 53.49 | Avg Reward (Last 100): 57.47 | Steps: 16 | Epsilon: 0.609 | Successes: 15
# Episode 20 | Total Reward: 55.21 | Avg Reward (Last 100): 57.36 | Steps: 29 | Epsilon: 0.600 | Successes: 16
# Episode 21 | Total Reward: 53.84 | Avg Reward (Last 100): 57.19 | Steps: 20 | Epsilon: 0.594 | Successes: 17
# Episode 92 | Total Reward: 51.53 | Avg Reward (Last 100): 55.26 | Steps: 7 | Epsilon: 0.250 | Successes: 87
# Episode 93 | Total Reward: 51.21 | Avg Reward (Last 100): 55.21 | Steps: 5 | Epsilon: 0.249 | Successes: 88
# Episode 94 | Total Reward: 51.43 | Avg Reward (Last 100): 55.17 | Steps: 6 | Epsilon: 0.249 | Successes: 89
# Episode 95 | Total Reward: 64.43 | Avg Reward (Last 100): 55.27 | Steps: 64 | Epsilon: 0.241 | Successes: 90
# Episode 96 | Total Reward: 51.21 | Avg Reward (Last 100): 55.23 | Steps: 5 | Epsilon: 0.240 | Successes: 91
# Episode 97 | Total Reward: 51.90 | Avg Reward (Last 100): 55.19 | Steps: 8 | Epsilon: 0.239 | Successes: 92
# Episode 98 | Total Reward: 51.21 | Avg Reward (Last 100): 55.15 | Steps: 5 | Epsilon: 0.239 | Successes: 93
# Episode 99 | Total Reward: 51.36 | Avg Reward (Last 100): 55.11 | Steps: 6 | Epsilon: 0.238 | Successes: 94
# Episode 100 | Total Reward: 51.58 | Avg Reward (Last 100): 55.08 | Steps: 7 | Epsilon: 0.237 | Successes: 95
# Episode 101 | Total Reward: 51.58 | Avg Reward (Last 100): 55.00 | Steps: 7 | Epsilon: 0.236 | Successes: 96
# Episode 102 | Total Reward: 52.65 | Avg Reward (Last 100): 54.99 | Steps: 12 | Epsilon: 0.235 | Successes: 97
# Episode 103 | Total Reward: 68.58 | Avg Reward (Last 100): 55.24 | Steps: 69 | Epsilon: 0.227 | Successes: 98
# Episode 104 | Total Reward: 54.18 | Avg Reward (Last 100): 55.16 | Steps: 200 | Epsilon: 0.205 | Successes: 98
# Episode 105 | Total Reward: 54.13 | Avg Reward (Last 100): 55.28 | Steps: 200 | Epsilon: 0.186 | Successes: 98
# Episode 106 | Total Reward: 54.01 | Avg Reward (Last 100): 55.26 | Steps: 200 | Epsilon: 0.168 | Successes: 98
# Episode 107 | Total Reward: 76.98 | Avg Reward (Last 100): 55.59 | Steps: 107 | Epsilon: 0.159 | Successes: 99
# Episode 108 | Total Reward: 52.35 | Avg Reward (Last 100): 55.51 | Steps: 10 | Epsilon: 0.159 | Successes: 100
# Episode 109 | Total Reward: 51.21 | Avg Reward (Last 100): 55.60 | Steps: 5 | Epsilon: 0.158 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 59.01
# Test 1: Success | Steps: 5
# Test 2: Success | Steps: 5
# Test 3: Success | Steps: 5
# Test 4: Success | Steps: 5
# Test 5: Success | Steps: 5
# Test 6: Success | Steps: 5
# Test 7: Success | Steps: 5
# Test 8: Success | Steps: 5
# Test 9: Success | Steps: 5
# Test 10: Success | Steps: 5
#
# Success Rate: 100% | Avg Steps per Episode: 5.00
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 62.22 | Avg Reward (Last 100): 62.22 | Steps: 58 | Epsilon: 0.971 | Successes: 1
# Episode 2 | Total Reward: 47.69 | Avg Reward (Last 100): 54.96 | Steps: 200 | Epsilon: 0.879 | Successes: 1
# Episode 97 | Total Reward: 52.18 | Avg Reward (Last 100): 53.30 | Steps: 9 | Epsilon: 0.429 | Successes: 96
# Episode 98 | Total Reward: 52.50 | Avg Reward (Last 100): 53.29 | Steps: 11 | Epsilon: 0.427 | Successes: 97
# Episode 99 | Total Reward: 52.08 | Avg Reward (Last 100): 53.28 | Steps: 9 | Epsilon: 0.425 | Successes: 98
# Episode 100 | Total Reward: 53.68 | Avg Reward (Last 100): 53.28 | Steps: 17 | Epsilon: 0.421 | Successes: 99
# Episode 101 | Total Reward: 52.75 | Avg Reward (Last 100): 53.19 | Steps: 13 | Epsilon: 0.419 | Successes: 100
# Episode 102 | Total Reward: 51.76 | Avg Reward (Last 100): 53.23 | Steps: 8 | Epsilon: 0.417 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 62.22
# Test 1: Success | Steps: 5
# Test 2: Success | Steps: 5
# Test 3: Success | Steps: 5
# Test 4: Success | Steps: 5
# Test 5: Success | Steps: 5
# Test 6: Success | Steps: 5
# Test 7: Success | Steps: 5
# Test 8: Success | Steps: 5
# Test 9: Success | Steps: 5
# Test 10: Success | Steps: 5
#
# Success Rate: 100% | Avg Steps per Episode: 5.00
# ¡El maze fue resuelto por al menos un agente!
#
# ===== Ejecución 2 de 5 =====
#
# ----- Intento de entrenamiento 1 -----
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 58.88 | Avg Reward (Last 100): 58.88 | Steps: 29 | Epsilon: 1.000 | Successes: 1
# Episode 2 | Total Reward: 63.61 | Avg Reward (Last 100): 61.25 | Steps: 42 | Epsilon: 1.000 | Successes: 2
# Episode 3 | Total Reward: 57.72 | Avg Reward (Last 100): 60.07 | Steps: 29 | Epsilon: 1.000 | Successes: 3
# Episode 4 | Total Reward: 63.45 | Avg Reward (Last 100): 60.92 | Steps: 46 | Epsilon: 1.000 | Successes: 4
# Episode 5 | Total Reward: 98.35 | Avg Reward (Last 100): 68.40 | Steps: 156 | Epsilon: 1.000 | Successes: 5
# Episode 6 | Total Reward: 67.34 | Avg Reward (Last 100): 68.23 | Steps: 55 | Epsilon: 1.000 | Successes: 6
# Episode 7 | Total Reward: 73.11 | Avg Reward (Last 100): 68.92 | Steps: 68 | Epsilon: 1.000 | Successes: 7
# Episode 8 | Total Reward: 60.36 | Avg Reward (Last 100): 67.85 | Steps: 31 | Epsilon: 1.000 | Successes: 8
# Episode 9 | Total Reward: 51.79 | Avg Reward (Last 100): 66.07 | Steps: 6 | Epsilon: 1.000 | Successes: 9
# Episode 10 | Total Reward: 86.82 | Avg Reward (Last 100): 68.14 | Steps: 129 | Epsilon: 0.961 | Successes: 10
# Episode 11 | Total Reward: 63.21 | Avg Reward (Last 100): 67.69 | Steps: 44 | Epsilon: 0.940 | Successes: 11
# Episode 12 | Total Reward: 75.64 | Avg Reward (Last 100): 68.36 | Steps: 81 | Epsilon: 0.903 | Successes: 12
# Episode 84 | Total Reward: 52.03 | Avg Reward (Last 100): 61.53 | Steps: 7 | Epsilon: 0.272 | Successes: 83
# Episode 85 | Total Reward: 52.68 | Avg Reward (Last 100): 61.42 | Steps: 9 | Epsilon: 0.271 | Successes: 84
# Episode 86 | Total Reward: 53.38 | Avg Reward (Last 100): 61.33 | Steps: 12 | Epsilon: 0.269 | Successes: 85
# Episode 87 | Total Reward: 51.78 | Avg Reward (Last 100): 61.22 | Steps: 6 | Epsilon: 0.268 | Successes: 86
# Episode 88 | Total Reward: 52.10 | Avg Reward (Last 100): 61.12 | Steps: 7 | Epsilon: 0.267 | Successes: 87
# Episode 89 | Total Reward: 51.46 | Avg Reward (Last 100): 61.01 | Steps: 5 | Epsilon: 0.267 | Successes: 88
# Episode 90 | Total Reward: 51.97 | Avg Reward (Last 100): 60.91 | Steps: 7 | Epsilon: 0.266 | Successes: 89
# Episode 91 | Total Reward: 52.73 | Avg Reward (Last 100): 60.82 | Steps: 9 | Epsilon: 0.265 | Successes: 90
# Episode 92 | Total Reward: 51.47 | Avg Reward (Last 100): 60.72 | Steps: 5 | Epsilon: 0.264 | Successes: 91
# Episode 93 | Total Reward: 52.91 | Avg Reward (Last 100): 60.63 | Steps: 10 | Epsilon: 0.263 | Successes: 92
# Episode 94 | Total Reward: 51.46 | Avg Reward (Last 100): 60.54 | Steps: 5 | Epsilon: 0.262 | Successes: 93
# Episode 95 | Total Reward: 52.75 | Avg Reward (Last 100): 60.45 | Steps: 9 | Epsilon: 0.261 | Successes: 94
# Episode 96 | Total Reward: 52.68 | Avg Reward (Last 100): 60.37 | Steps: 9 | Epsilon: 0.260 | Successes: 95
# Episode 97 | Total Reward: 52.12 | Avg Reward (Last 100): 60.29 | Steps: 8 | Epsilon: 0.259 | Successes: 96
# Episode 98 | Total Reward: 51.46 | Avg Reward (Last 100): 60.20 | Steps: 5 | Epsilon: 0.258 | Successes: 97
# Episode 99 | Total Reward: 51.46 | Avg Reward (Last 100): 60.11 | Steps: 5 | Epsilon: 0.257 | Successes: 98
# Episode 100 | Total Reward: 53.55 | Avg Reward (Last 100): 60.04 | Steps: 14 | Epsilon: 0.255 | Successes: 99
# Episode 101 | Total Reward: 52.05 | Avg Reward (Last 100): 59.98 | Steps: 7 | Epsilon: 0.255 | Successes: 100
# Episode 102 | Total Reward: 51.46 | Avg Reward (Last 100): 59.85 | Steps: 5 | Epsilon: 0.254 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 68.92
# Test 1: Success | Steps: 5
# Test 2: Success | Steps: 5
# Test 3: Success | Steps: 5
# Test 4: Success | Steps: 5
# Test 5: Success | Steps: 5
# Test 6: Success | Steps: 5
# Test 7: Success | Steps: 5
# Test 8: Success | Steps: 5
# Test 9: Success | Steps: 5
# Test 10: Success | Steps: 5
#
# Success Rate: 100% | Avg Steps per Episode: 5.00
# Starting training for 3000 episodes...
# Episode 95 | Total Reward: 51.47 | Avg Reward (Last 100): 54.93 | Steps: 5 | Epsilon: 0.466 | Successes: 95
# Episode 96 | Total Reward: 51.47 | Avg Reward (Last 100): 54.90 | Steps: 5 | Epsilon: 0.465 | Successes: 96
# Episode 97 | Total Reward: 51.47 | Avg Reward (Last 100): 54.86 | Steps: 5 | Epsilon: 0.464 | Successes: 97
# Episode 98 | Total Reward: 54.18 | Avg Reward (Last 100): 54.85 | Steps: 13 | Epsilon: 0.461 | Successes: 98
# Episode 99 | Total Reward: 51.47 | Avg Reward (Last 100): 54.82 | Steps: 5 | Epsilon: 0.459 | Successes: 99
# Episode 100 | Total Reward: 52.43 | Avg Reward (Last 100): 54.80 | Steps: 8 | Epsilon: 0.458 | Successes: 100
# Episode 101 | Total Reward: 52.37 | Avg Reward (Last 100): 54.75 | Steps: 8 | Epsilon: 0.456 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 63.63
# Test 1: Success | Steps: 5
# Test 2: Success | Steps: 5
# Test 3: Success | Steps: 5
# Test 4: Success | Steps: 5
# Test 5: Success | Steps: 5
# Test 6: Success | Steps: 5
# Test 7: Success | Steps: 5
# Test 8: Success | Steps: 5
# Test 9: Success | Steps: 5
# Test 10: Success | Steps: 5
#
# Success Rate: 100% | Avg Steps per Episode: 5.00
# ¡El maze fue resuelto por al menos un agente!
#
# ===== Ejecución 3 de 5 =====
#
# ----- Intento de entrenamiento 1 -----
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 71.74 | Avg Reward (Last 100): 71.74 | Steps: 70 | Epsilon: 1.000 | Successes: 1
# Episode 2 | Total Reward: 71.13 | Avg Reward (Last 100): 71.43 | Steps: 84 | Epsilon: 1.000 | Successes: 2
# Episode 3 | Total Reward: 64.31 | Avg Reward (Last 100): 69.06 | Steps: 59 | Epsilon: 1.000 | Successes: 3
# Episode 4 | Total Reward: 72.29 | Avg Reward (Last 100): 69.87 | Steps: 92 | Epsilon: 1.000 | Successes: 4
# Episode 5 | Total Reward: 45.35 | Avg Reward (Last 100): 64.96 | Steps: 200 | Epsilon: 1.000 | Successes: 4
# Episode 6 | Total Reward: 70.02 | Avg Reward (Last 100): 65.81 | Steps: 68 | Epsilon: 0.969 | Successes: 5
# Episode 7 | Total Reward: 53.45 | Avg Reward (Last 100): 64.04 | Steps: 12 | Epsilon: 0.964 | Successes: 6
# ...
# Episode 66 | Total Reward: 57.50 | Avg Reward (Last 100): 57.22 | Steps: 23 | Epsilon: 0.549 | Successes: 66
# Episode 67 | Total Reward: 51.13 | Avg Reward (Last 100): 57.13 | Steps: 4 | Epsilon: 0.548 | Successes: 67
# Episode 68 | Total Reward: 53.43 | Avg Reward (Last 100): 57.08 | Steps: 12 | Epsilon: 0.545 | Successes: 68
# Episode 69 | Total Reward: 51.14 | Avg Reward (Last 100): 56.99 | Steps: 4 | Epsilon: 0.544 | Successes: 69
# Episode 70 | Total Reward: 54.26 | Avg Reward (Last 100): 56.95 | Steps: 16 | Epsilon: 0.539 | Successes: 70
# Episode 94 | Total Reward: 51.99 | Avg Reward (Last 100): 55.82 | Steps: 7 | Epsilon: 0.484 | Successes: 94
# Episode 95 | Total Reward: 54.02 | Avg Reward (Last 100): 55.80 | Steps: 15 | Epsilon: 0.480 | Successes: 95
# Episode 96 | Total Reward: 54.43 | Avg Reward (Last 100): 55.79 | Steps: 15 | Epsilon: 0.477 | Successes: 96
# Episode 97 | Total Reward: 51.13 | Avg Reward (Last 100): 55.74 | Steps: 4 | Epsilon: 0.476 | Successes: 97
# Episode 98 | Total Reward: 51.13 | Avg Reward (Last 100): 55.69 | Steps: 4 | Epsilon: 0.475 | Successes: 98
# Episode 99 | Total Reward: 51.13 | Avg Reward (Last 100): 55.65 | Steps: 4 | Epsilon: 0.474 | Successes: 99
# Episode 100 | Total Reward: 53.47 | Avg Reward (Last 100): 55.63 | Steps: 15 | Epsilon: 0.470 | Successes: 100
# Episode 101 | Total Reward: 51.61 | Avg Reward (Last 100): 55.02 | Steps: 6 | Epsilon: 0.469 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 112.13
# Test 1: Success | Steps: 4
# Test 2: Success | Steps: 4
# Test 3: Success | Steps: 4
# Test 4: Success | Steps: 4
# Test 5: Success | Steps: 4
# Test 6: Success | Steps: 4
# Test 7: Success | Steps: 4
# Test 8: Success | Steps: 4
# Test 9: Success | Steps: 4
# Test 10: Success | Steps: 4
#
# Success Rate: 100% | Avg Steps per Episode: 4.00
# Starting training for 3000 episodes...
# Episode 1 | Total Reward: 64.05 | Avg Reward (Last 100): 64.05 | Steps: 200 | Epsilon: 0.905 | Successes: 0
# Episode 2 | Total Reward: 70.71 | Avg Reward (Last 100): 67.38 | Steps: 63 | Epsilon: 0.877 | Successes: 1
# Episode 3 | Total Reward: 73.36 | Avg Reward (Last 100): 69.37 | Steps: 70 | Epsilon: 0.847 | Successes: 2
# Episode 4 | Total Reward: 66.33 | Avg Reward (Last 100): 68.61 | Steps: 77 | Epsilon: 0.815 | Successes: 3
# Episode 5 | Total Reward: 72.78 | Avg Reward (Last 100): 69.45 | Steps: 78 | Epsilon: 0.783 | Successes: 4
# Episode 6 | Total Reward: 52.36 | Avg Reward (Last 100): 66.60 | Steps: 8 | Epsilon: 0.780 | Successes: 5
# Episode 7 | Total Reward: 52.62 | Avg Reward (Last 100): 64.60 | Steps: 10 | Epsilon: 0.776 | Successes: 6
# Episode 8 | Total Reward: 63.71 | Avg Reward (Last 100): 64.49 | Steps: 48 | Epsilon: 0.758 | Successes: 7
# Episode 9 | Total Reward: 52.10 | Avg Reward (Last 100): 63.11 | Steps: 7 | Epsilon: 0.755 | Successes: 8
# Episode 10 | Total Reward: 55.39 | Avg Reward (Last 100): 62.34 | Steps: 20 | Epsilon: 0.748 | Successes: 9
# Episode 11 | Total Reward: 53.17 | Avg Reward (Last 100): 61.51 | Steps: 11 | Epsilon: 0.744 | Successes: 10
# Episode 12 | Total Reward: 60.96 | Avg Reward (Last 100): 61.46 | Steps: 35 | Epsilon: 0.731 | Successes: 11
# Episode 83 | Total Reward: 53.34 | Avg Reward (Last 100): 54.28 | Steps: 11 | Epsilon: 0.502 | Successes: 82
# Episode 84 | Total Reward: 51.54 | Avg Reward (Last 100): 54.25 | Steps: 6 | Epsilon: 0.500 | Successes: 83
# Episode 85 | Total Reward: 54.54 | Avg Reward (Last 100): 54.25 | Steps: 15 | Epsilon: 0.497 | Successes: 84
# Episode 86 | Total Reward: 51.40 | Avg Reward (Last 100): 54.22 | Steps: 5 | Epsilon: 0.496 | Successes: 85
# Episode 87 | Total Reward: 51.62 | Avg Reward (Last 100): 54.19 | Steps: 6 | Epsilon: 0.494 | Successes: 86
# Episode 88 | Total Reward: 51.13 | Avg Reward (Last 100): 54.16 | Steps: 4 | Epsilon: 0.493 | Successes: 87
# Episode 89 | Total Reward: 51.15 | Avg Reward (Last 100): 54.12 | Steps: 4 | Epsilon: 0.492 | Successes: 88
# Episode 90 | Total Reward: 56.09 | Avg Reward (Last 100): 54.14 | Steps: 21 | Epsilon: 0.487 | Successes: 89
# Episode 91 | Total Reward: 52.69 | Avg Reward (Last 100): 54.13 | Steps: 9 | Epsilon: 0.485 | Successes: 90
# Episode 92 | Total Reward: 52.87 | Avg Reward (Last 100): 54.11 | Steps: 10 | Epsilon: 0.482 | Successes: 91
# Episode 93 | Total Reward: 51.77 | Avg Reward (Last 100): 54.09 | Steps: 6 | Epsilon: 0.481 | Successes: 92
# Episode 94 | Total Reward: 52.44 | Avg Reward (Last 100): 54.07 | Steps: 8 | Epsilon: 0.479 | Successes: 93
# Episode 95 | Total Reward: 53.14 | Avg Reward (Last 100): 54.06 | Steps: 10 | Epsilon: 0.477 | Successes: 94
# Episode 96 | Total Reward: 51.75 | Avg Reward (Last 100): 54.04 | Steps: 6 | Epsilon: 0.475 | Successes: 95
# Episode 97 | Total Reward: 51.45 | Avg Reward (Last 100): 54.01 | Steps: 5 | Epsilon: 0.474 | Successes: 96
# Episode 98 | Total Reward: 51.97 | Avg Reward (Last 100): 53.99 | Steps: 7 | Epsilon: 0.472 | Successes: 97
# Episode 99 | Total Reward: 52.42 | Avg Reward (Last 100): 53.97 | Steps: 8 | Epsilon: 0.470 | Successes: 98
# Episode 100 | Total Reward: 52.53 | Avg Reward (Last 100): 53.96 | Steps: 9 | Epsilon: 0.468 | Successes: 99
# Episode 101 | Total Reward: 52.56 | Avg Reward (Last 100): 53.84 | Steps: 9 | Epsilon: 0.466 | Successes: 100
# Episode 102 | Total Reward: 51.13 | Avg Reward (Last 100): 53.65 | Steps: 4 | Epsilon: 0.465 | Successes: 101
# Early stopping training as agent has reached the goal more than 100 times.
# Training completed! Best average reward: 69.45
# Test 1: Success | Steps: 4
# Test 2: Success | Steps: 4
# Test 3: Success | Steps: 4
# Test 4: Success | Steps: 4
# Test 5: Success | Steps: 4
# Test 6: Success | Steps: 4
# Test 7: Success | Steps: 4
# Test 8: Success | Steps: 4
# Test 9: Success | Steps: 4
# Test 10: Success | Steps: 4
#
# Success Rate: 100% | Avg Steps per Episode: 4.00
# ¡El maze fue resuelto por al menos un agente!
